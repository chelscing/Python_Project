# %% [markdown]
# The purpose of this section of the project addresses finding all of the hotels in Los Angeles in order for a customer to choose one based on personal preferences. The data consists of a myriad of attributes, such as: rating, price, and zip code.
#
# We will use this information along with the other parts of the project to demonatrate a user being able to make travel plans within our application.

# %%
import numpy as np
import requests 
import pickle
import pandas as pd 
from matplotlib import pyplot as plt  

# %matplotlib inline

# %% [markdown]
# API connects to Yelp to retrieve data about hotels in Los Angeles, then downloads it into a file to be then opened into a pandas DataFrame.

# %%
i = 0
d = []

for i in range(33):
    
    URL = 'https://api.yelp.com/v3/businesses/search'
    location = 'Los+Angeles'
    limit = 50
    offset = 51 + i
    term = 'hotels'
    PARAMS = {'location':location,
              'limit' : limit,
              'term' : term,
              'offset': offset
             } 
    headers = {"Authorization": "Bearer 6ju26BLdIk_lamRrEmS4v0LHrrENmiTMya0Mjnf2l3cOH3Lr0FnYwINvSIOqsnNrAP7meRKSNCW_F0WQMMPaw_H59LycM9ZKyQyUpQLS-098pjtnidQVPg3wRuK3W3Yx"
    }

    r = requests.request('GET', URL, headers= headers, params = PARAMS)
          
    d = d + r.json()['businesses'] 
 
with open('Downloads\hotel.txt','wb') as fp:
    pickle.dump(d, fp)
with open('Downloads\hotel.txt', 'rb') as fp:
    b = pickle.load(fp)

df = pd.DataFrame(b) 
print(df)
# Out:
#                                                   alias  \
# 0                     the-bel-air-treehouse-los-angeles
# 1     h-hotel-los-angeles-curio-collection-by-hilton...
# 2                 the-hollywood-roosevelt-los-angeles-2
# 3                              miyako-hotel-los-angeles
# 4                            west-end-hotel-los-angeles
# 5                           the-carlyle-inn-los-angeles
# 6     hyatt-regency-los-angeles-international-airpor...
# 7                              tuck-hotel-los-angeles-2
# 8                sheraton-grand-los-angeles-los-angeles
# 9     courtyard-by-marriott-los-angeles-l-a-live-los...
# 10    courtyard-by-marriott-los-angeles-lax-century-...
# 11    intercontinental-los-angeles-downtown-los-ange...
# 12                   kimpton-hotel-wilshire-los-angeles
# 13                    loews-hollywood-hotel-los-angeles
# 14                 hollywood-historic-hotel-los-angeles
# 15         w-los-angeles-west-beverly-hills-los-angeles
# ...

# %% [markdown]
# Retrieving the name of all the column headers in the DataFrame

# %%
df.columns
# Out:
# Index([u'alias', u'categories', u'coordinates', u'display_phone', u'distance',
#        u'id', u'image_url', u'is_closed', u'location', u'name', u'phone',
#        u'price', u'rating', u'review_count', u'transactions', u'url'],
#       dtype='object')

# %%
Displaying the original DataFrame

# %%
df
# Out:
#                                                   alias  \
# 0                     the-bel-air-treehouse-los-angeles
# 1     h-hotel-los-angeles-curio-collection-by-hilton...
# 2                 the-hollywood-roosevelt-los-angeles-2
# 3                              miyako-hotel-los-angeles
# 4                            west-end-hotel-los-angeles
# 5                           the-carlyle-inn-los-angeles
# 6     hyatt-regency-los-angeles-international-airpor...
# 7                              tuck-hotel-los-angeles-2
# 8                sheraton-grand-los-angeles-los-angeles
# 9     courtyard-by-marriott-los-angeles-l-a-live-los...
# 10    courtyard-by-marriott-los-angeles-lax-century-...
# 11    intercontinental-los-angeles-downtown-los-ange...
# 12                   kimpton-hotel-wilshire-los-angeles
# 13                    loews-hollywood-hotel-los-angeles
# 14                 hollywood-historic-hotel-los-angeles
# 15         w-los-angeles-west-beverly-hills-los-angeles
# ...

# %% [markdown]
# Droppping "categories" column

# %%
df.drop("categories", axis =1, inplace=True)

# %% [markdown]
# Droppping "image_url" column

# %%
df.drop("image_url", axis =1, inplace=True) 
df
# Out:
#                                                   alias  \
# 0                     the-bel-air-treehouse-los-angeles
# 1     h-hotel-los-angeles-curio-collection-by-hilton...
# 2                 the-hollywood-roosevelt-los-angeles-2
# 3                              miyako-hotel-los-angeles
# 4                            west-end-hotel-los-angeles
# 5                           the-carlyle-inn-los-angeles
# 6     hyatt-regency-los-angeles-international-airpor...
# 7                              tuck-hotel-los-angeles-2
# 8                sheraton-grand-los-angeles-los-angeles
# 9     courtyard-by-marriott-los-angeles-l-a-live-los...
# 10    courtyard-by-marriott-los-angeles-lax-century-...
# 11    intercontinental-los-angeles-downtown-los-ange...
# 12                   kimpton-hotel-wilshire-los-angeles
# 13                    loews-hollywood-hotel-los-angeles
# 14                 hollywood-historic-hotel-los-angeles
# 15         w-los-angeles-west-beverly-hills-los-angeles
# ...

# %% [markdown]
# Filtering out hotels where they are closed

# %%
df[df["is_closed"]==False]
# Out:
#                                                   alias  \
# 0                     the-bel-air-treehouse-los-angeles
# 1     h-hotel-los-angeles-curio-collection-by-hilton...
# 2                 the-hollywood-roosevelt-los-angeles-2
# 3                              miyako-hotel-los-angeles
# 4                            west-end-hotel-los-angeles
# 5                           the-carlyle-inn-los-angeles
# 6     hyatt-regency-los-angeles-international-airpor...
# 7                              tuck-hotel-los-angeles-2
# 8                sheraton-grand-los-angeles-los-angeles
# 9     courtyard-by-marriott-los-angeles-l-a-live-los...
# 10    courtyard-by-marriott-los-angeles-lax-century-...
# 11    intercontinental-los-angeles-downtown-los-ange...
# 12                   kimpton-hotel-wilshire-los-angeles
# 13                    loews-hollywood-hotel-los-angeles
# 14                 hollywood-historic-hotel-los-angeles
# 15         w-los-angeles-west-beverly-hills-los-angeles
# ...

# %% [markdown]
# Droppping "transactions" column

# %%
df.drop("transactions", axis =1, inplace=True) 
df
# Out:
#                                                   alias  \
# 0                     the-bel-air-treehouse-los-angeles
# 1     h-hotel-los-angeles-curio-collection-by-hilton...
# 2                 the-hollywood-roosevelt-los-angeles-2
# 3                              miyako-hotel-los-angeles
# 4                            west-end-hotel-los-angeles
# 5                           the-carlyle-inn-los-angeles
# 6     hyatt-regency-los-angeles-international-airpor...
# 7                              tuck-hotel-los-angeles-2
# 8                sheraton-grand-los-angeles-los-angeles
# 9     courtyard-by-marriott-los-angeles-l-a-live-los...
# 10    courtyard-by-marriott-los-angeles-lax-century-...
# 11    intercontinental-los-angeles-downtown-los-ange...
# 12                   kimpton-hotel-wilshire-los-angeles
# 13                    loews-hollywood-hotel-los-angeles
# 14                 hollywood-historic-hotel-los-angeles
# 15         w-los-angeles-west-beverly-hills-los-angeles
# ...

# %% [markdown]
# Filtering out null values for price

# %%
df.dropna(subset=["price"], inplace=True)
df
# Out:
#                                                   alias  \
# 1     h-hotel-los-angeles-curio-collection-by-hilton...
# 2                 the-hollywood-roosevelt-los-angeles-2
# 3                              miyako-hotel-los-angeles
# 4                            west-end-hotel-los-angeles
# 5                           the-carlyle-inn-los-angeles
# 6     hyatt-regency-los-angeles-international-airpor...
# 7                              tuck-hotel-los-angeles-2
# 8                sheraton-grand-los-angeles-los-angeles
# 9     courtyard-by-marriott-los-angeles-l-a-live-los...
# 10    courtyard-by-marriott-los-angeles-lax-century-...
# 11    intercontinental-los-angeles-downtown-los-ange...
# 12                   kimpton-hotel-wilshire-los-angeles
# 13                    loews-hollywood-hotel-los-angeles
# 14                 hollywood-historic-hotel-los-angeles
# 15         w-los-angeles-west-beverly-hills-los-angeles
# 16                                   mr-c-los-angeles-2
# ...

# %% [markdown]
# Checking to see that no more null values are returned for price

# %%
df["price"].isnull().sum()
# Out:
# 0

# %% [markdown]
# Splitting dictionaries that are embedded within the "location" column into column headers

# %%
df = pd.concat([df.drop(["location"], axis=1), df["location"].apply(pd.Series)], axis=1)
df
# Out:
#                                                   alias  \
# 1     h-hotel-los-angeles-curio-collection-by-hilton...
# 2                 the-hollywood-roosevelt-los-angeles-2
# 3                              miyako-hotel-los-angeles
# 4                            west-end-hotel-los-angeles
# 5                           the-carlyle-inn-los-angeles
# 6     hyatt-regency-los-angeles-international-airpor...
# 7                              tuck-hotel-los-angeles-2
# 8                sheraton-grand-los-angeles-los-angeles
# 9     courtyard-by-marriott-los-angeles-l-a-live-los...
# 10    courtyard-by-marriott-los-angeles-lax-century-...
# 11    intercontinental-los-angeles-downtown-los-ange...
# 12                   kimpton-hotel-wilshire-los-angeles
# 13                    loews-hollywood-hotel-los-angeles
# 14                 hollywood-historic-hotel-los-angeles
# 15         w-los-angeles-west-beverly-hills-los-angeles
# 16                                   mr-c-los-angeles-2
# ...

# %% [markdown]
# Splitting dictionaries that are embedded within the "coordinates" column into column headers

# %%
df = pd.concat([df.drop(["coordinates"], axis=1), df["coordinates"].apply(pd.Series)], axis=1)
df
# Out:
#                                                   alias   display_phone  \
# 1     h-hotel-los-angeles-curio-collection-by-hilton...  (310) 215-3000
# 2                 the-hollywood-roosevelt-los-angeles-2  (323) 856-1970
# 3                              miyako-hotel-los-angeles  (213) 617-2000
# 4                            west-end-hotel-los-angeles  (310) 479-1823
# 5                           the-carlyle-inn-los-angeles  (310) 275-4445
# 6     hyatt-regency-los-angeles-international-airpor...  (424) 702-1234
# 7                              tuck-hotel-los-angeles-2  (213) 947-3815
# 8                sheraton-grand-los-angeles-los-angeles  (213) 488-3500
# 9     courtyard-by-marriott-los-angeles-l-a-live-los...  (213) 443-9222
# 10    courtyard-by-marriott-los-angeles-lax-century-...  (310) 649-1400
# 11    intercontinental-los-angeles-downtown-los-ange...  (213) 688-7777
# 12                   kimpton-hotel-wilshire-los-angeles  (323) 852-6000
# ...

# %% [markdown]
# Droppping "address2" column

# %%
df.drop("address2", axis =1, inplace=True) 
df
# Out:
#                                                   alias   display_phone  \
# 1     h-hotel-los-angeles-curio-collection-by-hilton...  (310) 215-3000
# 2                 the-hollywood-roosevelt-los-angeles-2  (323) 856-1970
# 3                              miyako-hotel-los-angeles  (213) 617-2000
# 4                            west-end-hotel-los-angeles  (310) 479-1823
# 5                           the-carlyle-inn-los-angeles  (310) 275-4445
# 6     hyatt-regency-los-angeles-international-airpor...  (424) 702-1234
# 7                              tuck-hotel-los-angeles-2  (213) 947-3815
# 8                sheraton-grand-los-angeles-los-angeles  (213) 488-3500
# 9     courtyard-by-marriott-los-angeles-l-a-live-los...  (213) 443-9222
# 10    courtyard-by-marriott-los-angeles-lax-century-...  (310) 649-1400
# 11    intercontinental-los-angeles-downtown-los-ange...  (213) 688-7777
# 12                   kimpton-hotel-wilshire-los-angeles  (323) 852-6000
# ...

# %%
Droppping "address3" column

# %%
df.drop("address3", axis =1, inplace=True) 
df
# Out:
#                                                   alias   display_phone  \
# 1     h-hotel-los-angeles-curio-collection-by-hilton...  (310) 215-3000
# 2                 the-hollywood-roosevelt-los-angeles-2  (323) 856-1970
# 3                              miyako-hotel-los-angeles  (213) 617-2000
# 4                            west-end-hotel-los-angeles  (310) 479-1823
# 5                           the-carlyle-inn-los-angeles  (310) 275-4445
# 6     hyatt-regency-los-angeles-international-airpor...  (424) 702-1234
# 7                              tuck-hotel-los-angeles-2  (213) 947-3815
# 8                sheraton-grand-los-angeles-los-angeles  (213) 488-3500
# 9     courtyard-by-marriott-los-angeles-l-a-live-los...  (213) 443-9222
# 10    courtyard-by-marriott-los-angeles-lax-century-...  (310) 649-1400
# 11    intercontinental-los-angeles-downtown-los-ange...  (213) 688-7777
# 12                   kimpton-hotel-wilshire-los-angeles  (323) 852-6000
# ...

# %%
#rating_group = df.groupby(["rating"])["name"].aggregate(np.sum).sort_values(ascending = False)
#plt.ylabel("Rating")
#plt.title("Blank")
#ax = rating_group.plot(kind = "bar")
#plt.show()

# %% [markdown]
# Creating a histogram that shows the frequency of the number of hotels in each rating

# %%
df.hist(column="rating", bins = 8, grid=False, figsize=(12,8), color='#86bf91', zorder=2, rwidth=0.9) 

plt.title("")

# Set x-axis label
plt.xlabel("Rating")

# Set y-axis label
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# Creating a bar graph that shows the hotel names that have a rating of 4.0 and higher

# %% [markdown]
# Creating a bar graph that shows the hotel names that have a price range of $$ and lower

# %%
df.plot.bar(x="name", y="rating", rot=0, grid=False, figsize=(12,8), color='#86bf91', zorder=2, rwidth=0.9) 

#plt.title("")

# Set x-axis label
#plt.xlabel("Hotel Name")

# Set y-axis label
#plt.ylabel("Rating")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-6747aacd31cb> in <module>()
# ----> 1 ax = df.plot.bar(x="name", y="rating", rot=0, grid=False, figsize=(12,8), color='#86bf91', zorder=2, rwidth=0.9)
#       2 print(ax)
#       3 #plt.title("")
#       4
#       5 # Set x-axis label
#
# /Users/chelseahermond/anaconda2/lib/python2.7/site-packages/pandas/plotting/_core.pyc in bar(self, x, y, **kwds)
#    2714         axes : matplotlib.AxesSubplot or np.array of them
#    2715         """
# -> 2716         return self(kind='bar', x=x, y=y, **kwds)
#    2717
#    2718     def barh(self, x=None, y=None, **kwds):
#
# ...
